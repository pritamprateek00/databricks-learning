# %%
# %sql
USE CATALOG ecommerce;

CREATE SCHEMA IF NOT EXISTS raw;

DROP VOLUME IF EXISTS default.raw_landing;

CREATE EXTERNAL VOLUME IF NOT EXISTS raw.raw_landing
    LOCATION 'abfss://ecommerce-raw-data@stgecommerce151200.dfs.core.windows.net/'
    COMMENT 'Raw ADLS Gen2 landing for ecommerce';
